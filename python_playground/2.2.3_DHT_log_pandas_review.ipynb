# %%
import pandas as pd

# %%
df = pd.read_csv('DHT_log.csv', parse_dates=[0])

# %%
df.dtypes
# Out:
# datetime       datetime64[ns]
# humidity              float64
# temperature           float64
# dtype: object

# %%
df = df.set_index('datetime')
df
# Out:
#                      humidity  temperature
# datetime
# 2024-11-30 18:00:37      53.8         19.3
# 2024-11-30 18:00:38      53.8         19.3
# 2024-11-30 18:00:44      53.9         19.2
# 2024-11-30 18:00:45      53.8         19.3
# 2024-11-30 18:00:46      53.9         19.4
# ...                       ...          ...
# 2024-12-01 10:12:34      49.9         19.9
# 2024-12-01 10:15:34      46.0         19.9
# 2024-12-01 10:17:34      46.4         19.8
# 2024-12-01 10:18:34      46.6         19.8
# 2024-12-01 10:20:34      46.6         19.8
#
# [23860 rows x 2 columns]

# %%
df['temperature'].plot()
# df['temperature'].iloc[:30].plot()
# Out:
# <Axes: xlabel='datetime'>

# %%
_ = df.resample("1min").mean()
_['temperature'].plot(legend=True)
_['humidity'].plot(legend=True, secondary_y=True)
# df.index
# Out:
# <Axes: >
